# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# 2025-10-29 17:33:25,219 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=73, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2025-10-29 17:33:35,061 - vs2lab.lab1.clientserver.Server - INFO - Connected by ('127.0.0.1', 51896)
# 2025-10-29 17:34:02,394 - vs2lab.lab1.clientserver.Server - INFO - Connected by ('127.0.0.1', 50362)

# %% [markdown]
# Finished

# %%
server.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 server.close()
#
# AttributeError: 'Server' object has no attribute 'close'
