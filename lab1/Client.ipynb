# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.GET("Alice") # start the call and print echo
# Out:
# 2025-10-29 17:34:02,394 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=73, family=2, type=1, proto=0, laddr=('127.0.0.1', 50362), raddr=('127.0.0.1', 50007)>
# 2025-10-29 17:34:02,395 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# Alice:12345
# 'Alice:12345\n'

# %% [markdown]
# Finished.

# %%
client.close
# Out:
# <bound method Client.close of <clientserver.Client object at 0x7f0fe0d6de50>>
